# %%
import pandas as pd
import json
from dotenv import load_dotenv
import os
import re
    
load_dotenv()

# %%
df = pd.read_csv("combined_canada_rag_cleaned.csv")

# %%
df.head()
# Out:
#                      id                                                url  \
# 0  Alberta_1_1757152647  https://www.alberta.ca/careers-fisheries-manag...
# 1  Alberta_2_1757152647  https://www.alberta.ca/carrier-profiles-and-mo...
# 2  Alberta_3_1757152647     https://www.alberta.ca/careers-land-management
# 3  Alberta_4_1757152648  https://www.alberta.ca/careers-wildlife-manage...
# 4  Alberta_5_1757152648            https://www.alberta.ca/careers-agrology
#
#                                           title  \
# 0   Careers – Fisheries management | Alberta.ca
# 1  Carrier profiles and monitoring | Alberta.ca
# 2        Careers – Land management | Alberta.ca
# 3    Careers – Wildlife management | Alberta.ca
# 4               Careers – Agrology | Alberta.ca
#
#                                          description  \
# 0  A career in fisheries management offers many o...
# 1  Supports carriers' internal monitoring of on-r...
# 2  There are many rewarding career paths for land...
# 3  A career in wildlife management offers opportu...
# 4  Agrologists can find meaningful work managing ...
#
#                                              content province     timestamp  \
# 0  A career in fisheries management offers many o...  Alberta  1.757153e+09
# 1  \n\n\n\n  * Effective December 2020, the Roads...  Alberta  1.757153e+09
# 2  The Lands Division is responsible for providin...  Alberta  1.757153e+09
# 3  A career in Wildlife Management offers a contr...  Alberta  1.757153e+09
# 4  Consider a career that enables you to make a d...  Alberta  1.757153e+09
#
#    content_length language       source document_type
# 0            4794       en  alberta_gov          html
# 1            5891       en  alberta_gov          html
# 2            6423       en  alberta_gov          html
# 3            3919       en  alberta_gov          html
# 4            4653       en  alberta_gov          html

# %%
content_list = df[df["content_length"] < 10000]["content"].sample(20000).to_list()

# %%
import base64
import os
import json
import re
from google import genai
from google.genai import types
import random
from datetime import datetime
import time

# Rate limiting configuration
RATE_LIMITS = {
    "requests_per_minute": 30,
    "tokens_per_minute": 15000,
    "requests_per_day": 14400
}

class RateLimiter:
    def __init__(self):
      self.request_times = []
      self.token_counts = []
      self.daily_request = 0
      self.daily_reset = datetime.now().date()

    def estimate_tokens(self,text):
      """Rough token estimation (1 token ≈ 4 characters for English)"""
      return max(1, len(text) // 4)
    
    def wait_if_needed(self,prompt_text=""):

      # Reset daily counter if it's a new day
      current_date = datetime.now().date()
      if current_date != self.daily_reset:
        self.daily_request = 0
        self.daily_reset = current_date

      if self.daily_request >= RATE_LIMITS["requests_per_day"]:
        print("Daily limit reached. Waiting until tomorrow...")
        time.sleep(86400)
        self.daily_request = 0
        self.daily_reset = datetime.now().date()

      # check minute limit
      current_time = time.time()
      one_minute_ago = current_time - 60

      # remove request older than 1 minutes
      valid_indices = [i for i, t in enumerate(self.request_times) if t > one_minute_ago]
      self.request_times = [self.request_times[i] for i in valid_indices]
      self.token_counts = [self.token_counts[i] for i in valid_indices]

      current_tokens = self.estimate_tokens(prompt_text)
      total_tokens_last_minute = sum(self.token_counts) + current_tokens

      if total_tokens_last_minute >= RATE_LIMITS["tokens_per_minute"]:
        # Find when we can make the next request without exceeding token limit
          if self.request_times:
            oldest_request = min(self.request_times)
            wait_time = 60 - (current_time - oldest_request) + 1
            print(f"Rate limit reached. Waiting {wait_time:.1f} seconds....")
            time.sleep(wait_time)
            #reseting after waiting
            self.request_times = [time.time()]
            self.token_counts = [current_tokens]

          else:
            time.sleep(60)

      if len(self.request_times) >= RATE_LIMITS["requests_per_minute"]:
        oldest_request = min(self.request_times)
        wait_time = 60 - (current_time - oldest_request) + 1
        print(f"Rate limit reached. Waiting {wait_time:.1f} seconds....")
        time.sleep(wait_time)
        # update times after the waiting
        self.request_times = [time.time()]
        self.token_counts = [current_tokens]

      else:
        # add small random delay to avoid bursting
        time.sleep(random.uniform(0.1,0.5))

      # Recording the request
      self.request_times.append(time.time())
      self.token_counts.append(current_tokens)
      self.daily_request += 1

rate_limiter = RateLimiter()


def extract_json_from_data(result):
    """Extract JSON from the response text"""

    if not result or result.strip() == "":
       print("Empty response receive")
       return None, None
    
    try:
        json_match = re.findall(r"\{[\s\S]*\}", result)
        
        if not json_match:
            print("No JSON found in response")
            print(f"Response was: {result[:500]}...")  
            return None, None

        cleaned_text = json_match[0]
        json_data = json.loads(cleaned_text)
        triplet_list = [json_data["anchor"], json_data["positive"], json_data["negative"]]
        return json_data, triplet_list
    
    except (json.JSONDecodeError, KeyError, IndexError) as e:
        print(f"Error parsing JSON: {e}")
        print(f"Response text: {result[:500]}...") 
        return None, None

def generate(content):

  prompt_template = f"""


You are an expert in creating training data for embedding models. Your task is to generate **one** high-quality triplet in JSON format for semantic similarity fine-tuning.

## STRICT REQUIREMENTS:

**1. LANGUAGE DETECTION & CONSISTENCY:**
   - FIRST, detect the primary language of the document content
   - Use that SAME language for ALL THREE elements (anchor, positive, negative)
   - If document contains multiple languages, choose the dominant one consistently
   - Output language must match document's primary language

**2. POSITIVE QUALITY:**
   - Must be a COMPLETE, grammatically correct sentence from the document
   - Should directly answer the anchor question
   - Avoid incomplete sentences, fragments, or lists
   - Paraphrase if necessary but stay faithful to original meaning

**3. NEGATIVE DISTINCTION:**
   - Must be from a COMPLETELY DIFFERENT domain/service/topic
   - Should not share any keywords or concepts with the anchor
   - Different beneficiary groups, different government services, different intents

**4. CONTENT VALIDATION:**
   - Ensure positive is actually present in or directly inferrable from the document
   - Avoid technical gibberish or broken sentences
   - Use natural, conversational language

## LANGUAGE DETECTION GUIDE:
- If document contains French terms like "Québec", "procédures", "admissible" → Use FRENCH
- If document contains English terms only → Use ENGLISH  
- Be consistent throughout the triplet

## OUTPUT FORMAT (JSON ONLY):
{{
    "anchor": "question in detected language",
    "positive": "complete sentence answering question", 
    "negative": "different domain topic in same language"
}}

## BAD → GOOD EXAMPLES:

❌ BAD: Mixed languages, incomplete positives
✅ GOOD: 
{{
    "anchor": "Quelles mesures les propriétaires peuvent-ils prendre contre les punaises de lit?",
    "positive": "Les propriétaires peuvent instaurer différentes mesures pour prévenir et éliminer les punaises des lits.",
    "negative": "Quelles sont les exigences pour obtenir un permis de construction?"
}}

❌ BAD: Broken/grammatically incorrect positives  
✅ GOOD:
{{
    "anchor": "How long do plant breeders' rights last in Canada?",
    "positive": "Plant breeders receive legal protection for up to 25 years for trees and vines, and 20 years for other plant varieties.",
    "negative": "What are the requirements for importing agricultural products?"
}}

Document content:
{str(content)}


"""
  try:
    
    # Apply rate limiting before making the request

    rate_limiter.wait_if_needed(prompt_template)


    client = genai.Client(
          api_key = os.environ.get("GOOGLE_API_KEY"),
    )
        


    model = "gemma-3-27b-it"
    contents = [
          types.Content(
              role="user",
              parts=[
                  types.Part.from_text(text=prompt_template),
              ],
          ),
      ]
    generate_content_config = types.GenerateContentConfig(
      max_output_tokens=500
    )

    # Collect all chunks
    full_response = ""

    for chunk in client.models.generate_content_stream(
      model=model,
      contents=contents,
      config=generate_content_config,
      ):
      if chunk.text:
          full_response += chunk.text

    if not full_response.strip():
      print("Empty repsonse from API")
      return None, None
    
    json_data, triplet = extract_json_from_data(full_response)
    return json_data, triplet

  except Exception as e:

    if "429" in str(e) or "quota" in str(e).lower():
      # Specific handling for quota errors
      retry_seconds = 60  # Wait a full minute for token reset
      print(f"Quota exceeded. Waiting {retry_seconds} seconds...")
      time.sleep(retry_seconds)
      # Reset rate limiter after quota error
      rate_limiter.request_times = []
      rate_limiter.token_counts = []

    else:
      print(f"Error in generate function: {e}")

    return None, None
  


def main(content_list):
  json_data_list = []
  triplet_list = []
  counter = 0
  success_count = 0
  error_count = 0

  # Need to clean the file before generating
  open("triplet.json", "w").close()
  open("triplet_list.json", "w").close()

  for content in content_list:
    counter += 1

    print(f"\n--- Processing content {counter}/{len(content_list)} ---")
    
    try:
       
      json_data, triplet = generate(content)

      if json_data and triplet:
        
        json_data_list.append(json_data)
        triplet_list.append(triplet)
        success_count += 1
        print(f"✅ Successfully generated triplet {success_count}")

        if success_count %10 == 0:
           
          with open("triplet.json", "w") as f:
            json.dump(json_data_list, f, indent=2)

          with open("triplet_list.json", "w") as f:
            json.dump(triplet_list,f,indent=2)
          print(f"💾 Progress saved at {success_count} triplets")

      else:
        error_count += 1
        print(f"❌ Failed to generate triplet (Error #{error_count})")

    except Exception as e:
      error_count += 1
      print(f"🚨 Unexpected error in main loop: {e}")

    success_rate = (success_count/counter) * 100
    print(f"📊 Progress: {counter}/{len(content_list)} | Success : {success_count} | Errors : {error_count} | Rate : {success_rate:.1f}%")

    # Save final results

    if json_data_list:
      with open("triplet.json", "w") as f:
        json.dump(json_data_list, f, indent=2)
      with open("triplet_list.json", "w") as f:
        json.dump(triplet_list, f, indent=2)

    print(f"\nFinal results : {success_count} successfully triplets out of {counter} attempts")
    print(f"Total errors : {error_count}")
    print(f"Success rate: {(success_count/counter)*100:.1f}%")

  return json_data_list, triplet_list

# %%
def is_high_quality(content):
    # Skip if content is too short
    if len(content.strip()) < 50:
        return False
    
    # Skip if contains low-quality indicators
    low_quality_patterns = [
        r"error", r"captcha", r"server", r"bot", r"temporarily limited",
        r"page when trying to access", r"your browser", r"request.*understand",
        r"higher volume.*requests", r"network.*normal"
    ]
    
    content_lower = content.lower()
    if any(re.search(pattern, content_lower) for pattern in low_quality_patterns):
        return False
    
    # Additional quality checks
    if content_lower.count(".") < 2:  # Too few sentences
        return False
        
    return True

filtered_content_list = [content for content in content_list if is_high_quality(content)]

# %%
filtered_content_list

if __name__ == "__main__":
    if not filtered_content_list:
        print("Please define content_list with your documents")

    else:
        
        json_data_list, triplet_list = main(filtered_content_list[:10000])
# Out:
# --- Processing content 1/10000 ---
# ✅ Successfully generated triplet 1
# 📊 Progress: 1/10000 | Success : 1 | Errors : 0 | Rate : 100.0%
#
# Final results : 1 successfully triplets out of 1 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 2/10000 ---
# ✅ Successfully generated triplet 2
# 📊 Progress: 2/10000 | Success : 2 | Errors : 0 | Rate : 100.0%
#
# Final results : 2 successfully triplets out of 2 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 3/10000 ---
# ✅ Successfully generated triplet 3
# 📊 Progress: 3/10000 | Success : 3 | Errors : 0 | Rate : 100.0%
#
# Final results : 3 successfully triplets out of 3 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 4/10000 ---
# ✅ Successfully generated triplet 4
# 📊 Progress: 4/10000 | Success : 4 | Errors : 0 | Rate : 100.0%
#
# Final results : 4 successfully triplets out of 4 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 5/10000 ---
# ✅ Successfully generated triplet 5
# 📊 Progress: 5/10000 | Success : 5 | Errors : 0 | Rate : 100.0%
#
# Final results : 5 successfully triplets out of 5 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 6/10000 ---
# ✅ Successfully generated triplet 6
# 📊 Progress: 6/10000 | Success : 6 | Errors : 0 | Rate : 100.0%
#
# Final results : 6 successfully triplets out of 6 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 7/10000 ---
# ✅ Successfully generated triplet 7
# 📊 Progress: 7/10000 | Success : 7 | Errors : 0 | Rate : 100.0%
#
# Final results : 7 successfully triplets out of 7 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 8/10000 ---
# ✅ Successfully generated triplet 8
# 📊 Progress: 8/10000 | Success : 8 | Errors : 0 | Rate : 100.0%
#
# Final results : 8 successfully triplets out of 8 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 9/10000 ---
# ✅ Successfully generated triplet 9
# 📊 Progress: 9/10000 | Success : 9 | Errors : 0 | Rate : 100.0%
#
# Final results : 9 successfully triplets out of 9 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 10/10000 ---
# ✅ Successfully generated triplet 10
# 💾 Progress saved at 10 triplets
# 📊 Progress: 10/10000 | Success : 10 | Errors : 0 | Rate : 100.0%
#
# Final results : 10 successfully triplets out of 10 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 11/10000 ---
# Rate limit reached. Waiting 31.6 seconds....
# ✅ Successfully generated triplet 11
# 📊 Progress: 11/10000 | Success : 11 | Errors : 0 | Rate : 100.0%
#
# Final results : 11 successfully triplets out of 11 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 12/10000 ---
# ✅ Successfully generated triplet 12
# 📊 Progress: 12/10000 | Success : 12 | Errors : 0 | Rate : 100.0%
#
# Final results : 12 successfully triplets out of 12 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 13/10000 ---
# ✅ Successfully generated triplet 13
# 📊 Progress: 13/10000 | Success : 13 | Errors : 0 | Rate : 100.0%
#
# Final results : 13 successfully triplets out of 13 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 14/10000 ---
# ✅ Successfully generated triplet 14
# 📊 Progress: 14/10000 | Success : 14 | Errors : 0 | Rate : 100.0%
#
# Final results : 14 successfully triplets out of 14 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 15/10000 ---
# ✅ Successfully generated triplet 15
# 📊 Progress: 15/10000 | Success : 15 | Errors : 0 | Rate : 100.0%
#
# Final results : 15 successfully triplets out of 15 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 16/10000 ---
# ✅ Successfully generated triplet 16
# 📊 Progress: 16/10000 | Success : 16 | Errors : 0 | Rate : 100.0%
#
# Final results : 16 successfully triplets out of 16 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 17/10000 ---
# ✅ Successfully generated triplet 17
# 📊 Progress: 17/10000 | Success : 17 | Errors : 0 | Rate : 100.0%
#
# Final results : 17 successfully triplets out of 17 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 18/10000 ---
# ✅ Successfully generated triplet 18
# 📊 Progress: 18/10000 | Success : 18 | Errors : 0 | Rate : 100.0%
#
# Final results : 18 successfully triplets out of 18 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 19/10000 ---
# ✅ Successfully generated triplet 19
# 📊 Progress: 19/10000 | Success : 19 | Errors : 0 | Rate : 100.0%
#
# Final results : 19 successfully triplets out of 19 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 20/10000 ---
# Rate limit reached. Waiting 33.3 seconds....
# ✅ Successfully generated triplet 20
# 💾 Progress saved at 20 triplets
# 📊 Progress: 20/10000 | Success : 20 | Errors : 0 | Rate : 100.0%
#
# Final results : 20 successfully triplets out of 20 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 21/10000 ---
# ✅ Successfully generated triplet 21
# 📊 Progress: 21/10000 | Success : 21 | Errors : 0 | Rate : 100.0%
#
# Final results : 21 successfully triplets out of 21 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 22/10000 ---
# ✅ Successfully generated triplet 22
# 📊 Progress: 22/10000 | Success : 22 | Errors : 0 | Rate : 100.0%
#
# Final results : 22 successfully triplets out of 22 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 23/10000 ---
# ✅ Successfully generated triplet 23
# 📊 Progress: 23/10000 | Success : 23 | Errors : 0 | Rate : 100.0%
#
# Final results : 23 successfully triplets out of 23 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 24/10000 ---
# ✅ Successfully generated triplet 24
# 📊 Progress: 24/10000 | Success : 24 | Errors : 0 | Rate : 100.0%
#
# Final results : 24 successfully triplets out of 24 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 25/10000 ---
# ✅ Successfully generated triplet 25
# 📊 Progress: 25/10000 | Success : 25 | Errors : 0 | Rate : 100.0%
#
# Final results : 25 successfully triplets out of 25 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 26/10000 ---
# ✅ Successfully generated triplet 26
# 📊 Progress: 26/10000 | Success : 26 | Errors : 0 | Rate : 100.0%
#
# Final results : 26 successfully triplets out of 26 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 27/10000 ---
# ✅ Successfully generated triplet 27
# 📊 Progress: 27/10000 | Success : 27 | Errors : 0 | Rate : 100.0%
#
# Final results : 27 successfully triplets out of 27 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 28/10000 ---
# ✅ Successfully generated triplet 28
# 📊 Progress: 28/10000 | Success : 28 | Errors : 0 | Rate : 100.0%
#
# Final results : 28 successfully triplets out of 28 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 29/10000 ---
# ✅ Successfully generated triplet 29
# 📊 Progress: 29/10000 | Success : 29 | Errors : 0 | Rate : 100.0%
#
# Final results : 29 successfully triplets out of 29 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 30/10000 ---
# ✅ Successfully generated triplet 30
# 💾 Progress saved at 30 triplets
# 📊 Progress: 30/10000 | Success : 30 | Errors : 0 | Rate : 100.0%
#
# Final results : 30 successfully triplets out of 30 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 31/10000 ---
# Rate limit reached. Waiting 31.3 seconds....
# ✅ Successfully generated triplet 31
# 📊 Progress: 31/10000 | Success : 31 | Errors : 0 | Rate : 100.0%
#
# Final results : 31 successfully triplets out of 31 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 32/10000 ---
# ✅ Successfully generated triplet 32
# 📊 Progress: 32/10000 | Success : 32 | Errors : 0 | Rate : 100.0%
#
# Final results : 32 successfully triplets out of 32 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 33/10000 ---
# ✅ Successfully generated triplet 33
# 📊 Progress: 33/10000 | Success : 33 | Errors : 0 | Rate : 100.0%
#
# Final results : 33 successfully triplets out of 33 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 34/10000 ---
# ✅ Successfully generated triplet 34
# 📊 Progress: 34/10000 | Success : 34 | Errors : 0 | Rate : 100.0%
#
# Final results : 34 successfully triplets out of 34 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 35/10000 ---
# ✅ Successfully generated triplet 35
# 📊 Progress: 35/10000 | Success : 35 | Errors : 0 | Rate : 100.0%
#
# Final results : 35 successfully triplets out of 35 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 36/10000 ---
# ✅ Successfully generated triplet 36
# 📊 Progress: 36/10000 | Success : 36 | Errors : 0 | Rate : 100.0%
#
# Final results : 36 successfully triplets out of 36 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 37/10000 ---
# ✅ Successfully generated triplet 37
# 📊 Progress: 37/10000 | Success : 37 | Errors : 0 | Rate : 100.0%
#
# Final results : 37 successfully triplets out of 37 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 38/10000 ---
# ✅ Successfully generated triplet 38
# 📊 Progress: 38/10000 | Success : 38 | Errors : 0 | Rate : 100.0%
#
# Final results : 38 successfully triplets out of 38 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 39/10000 ---
# ✅ Successfully generated triplet 39
# 📊 Progress: 39/10000 | Success : 39 | Errors : 0 | Rate : 100.0%
#
# Final results : 39 successfully triplets out of 39 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 40/10000 ---
# ✅ Successfully generated triplet 40
# 💾 Progress saved at 40 triplets
# 📊 Progress: 40/10000 | Success : 40 | Errors : 0 | Rate : 100.0%
#
# Final results : 40 successfully triplets out of 40 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 41/10000 ---
# ✅ Successfully generated triplet 41
# 📊 Progress: 41/10000 | Success : 41 | Errors : 0 | Rate : 100.0%
#
# Final results : 41 successfully triplets out of 41 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 42/10000 ---
# ✅ Successfully generated triplet 42
# 📊 Progress: 42/10000 | Success : 42 | Errors : 0 | Rate : 100.0%
#
# Final results : 42 successfully triplets out of 42 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 43/10000 ---
# ✅ Successfully generated triplet 43
# 📊 Progress: 43/10000 | Success : 43 | Errors : 0 | Rate : 100.0%
#
# Final results : 43 successfully triplets out of 43 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 44/10000 ---
# Rate limit reached. Waiting 25.8 seconds....
# ✅ Successfully generated triplet 44
# 📊 Progress: 44/10000 | Success : 44 | Errors : 0 | Rate : 100.0%
#
# Final results : 44 successfully triplets out of 44 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 45/10000 ---
# ✅ Successfully generated triplet 45
# 📊 Progress: 45/10000 | Success : 45 | Errors : 0 | Rate : 100.0%
#
# Final results : 45 successfully triplets out of 45 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 46/10000 ---
# ✅ Successfully generated triplet 46
# 📊 Progress: 46/10000 | Success : 46 | Errors : 0 | Rate : 100.0%
#
# Final results : 46 successfully triplets out of 46 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 47/10000 ---
# ✅ Successfully generated triplet 47
# 📊 Progress: 47/10000 | Success : 47 | Errors : 0 | Rate : 100.0%
#
# Final results : 47 successfully triplets out of 47 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 48/10000 ---
# ✅ Successfully generated triplet 48
# 📊 Progress: 48/10000 | Success : 48 | Errors : 0 | Rate : 100.0%
#
# Final results : 48 successfully triplets out of 48 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 49/10000 ---
# ✅ Successfully generated triplet 49
# 📊 Progress: 49/10000 | Success : 49 | Errors : 0 | Rate : 100.0%
#
# Final results : 49 successfully triplets out of 49 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 50/10000 ---
# ✅ Successfully generated triplet 50
# 💾 Progress saved at 50 triplets
# 📊 Progress: 50/10000 | Success : 50 | Errors : 0 | Rate : 100.0%
#
# Final results : 50 successfully triplets out of 50 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 51/10000 ---
# ✅ Successfully generated triplet 51
# 📊 Progress: 51/10000 | Success : 51 | Errors : 0 | Rate : 100.0%
#
# Final results : 51 successfully triplets out of 51 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 52/10000 ---
# ✅ Successfully generated triplet 52
# 📊 Progress: 52/10000 | Success : 52 | Errors : 0 | Rate : 100.0%
#
# Final results : 52 successfully triplets out of 52 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 53/10000 ---
# Rate limit reached. Waiting 37.1 seconds....
# ✅ Successfully generated triplet 53
# 📊 Progress: 53/10000 | Success : 53 | Errors : 0 | Rate : 100.0%
#
# Final results : 53 successfully triplets out of 53 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 54/10000 ---
# ✅ Successfully generated triplet 54
# 📊 Progress: 54/10000 | Success : 54 | Errors : 0 | Rate : 100.0%
#
# Final results : 54 successfully triplets out of 54 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 55/10000 ---
# ✅ Successfully generated triplet 55
# 📊 Progress: 55/10000 | Success : 55 | Errors : 0 | Rate : 100.0%
#
# Final results : 55 successfully triplets out of 55 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 56/10000 ---
# ✅ Successfully generated triplet 56
# 📊 Progress: 56/10000 | Success : 56 | Errors : 0 | Rate : 100.0%
#
# Final results : 56 successfully triplets out of 56 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 57/10000 ---
# ✅ Successfully generated triplet 57
# 📊 Progress: 57/10000 | Success : 57 | Errors : 0 | Rate : 100.0%
#
# Final results : 57 successfully triplets out of 57 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 58/10000 ---
# ✅ Successfully generated triplet 58
# 📊 Progress: 58/10000 | Success : 58 | Errors : 0 | Rate : 100.0%
#
# Final results : 58 successfully triplets out of 58 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 59/10000 ---
# ✅ Successfully generated triplet 59
# 📊 Progress: 59/10000 | Success : 59 | Errors : 0 | Rate : 100.0%
#
# Final results : 59 successfully triplets out of 59 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 60/10000 ---
# ✅ Successfully generated triplet 60
# 💾 Progress saved at 60 triplets
# 📊 Progress: 60/10000 | Success : 60 | Errors : 0 | Rate : 100.0%
#
# Final results : 60 successfully triplets out of 60 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 61/10000 ---
# ✅ Successfully generated triplet 61
# 📊 Progress: 61/10000 | Success : 61 | Errors : 0 | Rate : 100.0%
#
# Final results : 61 successfully triplets out of 61 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 62/10000 ---
# Rate limit reached. Waiting 36.3 seconds....
# ✅ Successfully generated triplet 62
# 📊 Progress: 62/10000 | Success : 62 | Errors : 0 | Rate : 100.0%
#
# Final results : 62 successfully triplets out of 62 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 63/10000 ---
# ✅ Successfully generated triplet 63
# 📊 Progress: 63/10000 | Success : 63 | Errors : 0 | Rate : 100.0%
#
# Final results : 63 successfully triplets out of 63 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 64/10000 ---
# ✅ Successfully generated triplet 64
# 📊 Progress: 64/10000 | Success : 64 | Errors : 0 | Rate : 100.0%
#
# Final results : 64 successfully triplets out of 64 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 65/10000 ---
# ✅ Successfully generated triplet 65
# 📊 Progress: 65/10000 | Success : 65 | Errors : 0 | Rate : 100.0%
#
# Final results : 65 successfully triplets out of 65 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 66/10000 ---
# ✅ Successfully generated triplet 66
# 📊 Progress: 66/10000 | Success : 66 | Errors : 0 | Rate : 100.0%
#
# Final results : 66 successfully triplets out of 66 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 67/10000 ---
# ✅ Successfully generated triplet 67
# 📊 Progress: 67/10000 | Success : 67 | Errors : 0 | Rate : 100.0%
#
# Final results : 67 successfully triplets out of 67 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 68/10000 ---
# ✅ Successfully generated triplet 68
# 📊 Progress: 68/10000 | Success : 68 | Errors : 0 | Rate : 100.0%
#
# Final results : 68 successfully triplets out of 68 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 69/10000 ---
# ✅ Successfully generated triplet 69
# 📊 Progress: 69/10000 | Success : 69 | Errors : 0 | Rate : 100.0%
#
# Final results : 69 successfully triplets out of 69 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 70/10000 ---
# ✅ Successfully generated triplet 70
# 💾 Progress saved at 70 triplets
# 📊 Progress: 70/10000 | Success : 70 | Errors : 0 | Rate : 100.0%
#
# Final results : 70 successfully triplets out of 70 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 71/10000 ---
# Rate limit reached. Waiting 33.9 seconds....
# ✅ Successfully generated triplet 71
# 📊 Progress: 71/10000 | Success : 71 | Errors : 0 | Rate : 100.0%
#
# Final results : 71 successfully triplets out of 71 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 72/10000 ---
# ✅ Successfully generated triplet 72
# 📊 Progress: 72/10000 | Success : 72 | Errors : 0 | Rate : 100.0%
#
# Final results : 72 successfully triplets out of 72 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 73/10000 ---
# ✅ Successfully generated triplet 73
# 📊 Progress: 73/10000 | Success : 73 | Errors : 0 | Rate : 100.0%
#
# Final results : 73 successfully triplets out of 73 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 74/10000 ---
# ✅ Successfully generated triplet 74
# 📊 Progress: 74/10000 | Success : 74 | Errors : 0 | Rate : 100.0%
#
# Final results : 74 successfully triplets out of 74 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 75/10000 ---
# ✅ Successfully generated triplet 75
# 📊 Progress: 75/10000 | Success : 75 | Errors : 0 | Rate : 100.0%
#
# Final results : 75 successfully triplets out of 75 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 76/10000 ---
# ✅ Successfully generated triplet 76
# 📊 Progress: 76/10000 | Success : 76 | Errors : 0 | Rate : 100.0%
#
# Final results : 76 successfully triplets out of 76 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 77/10000 ---
# ✅ Successfully generated triplet 77
# 📊 Progress: 77/10000 | Success : 77 | Errors : 0 | Rate : 100.0%
#
# Final results : 77 successfully triplets out of 77 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 78/10000 ---
# ✅ Successfully generated triplet 78
# 📊 Progress: 78/10000 | Success : 78 | Errors : 0 | Rate : 100.0%
#
# Final results : 78 successfully triplets out of 78 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 79/10000 ---
# ✅ Successfully generated triplet 79
# 📊 Progress: 79/10000 | Success : 79 | Errors : 0 | Rate : 100.0%
#
# Final results : 79 successfully triplets out of 79 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 80/10000 ---
# ✅ Successfully generated triplet 80
# 💾 Progress saved at 80 triplets
# 📊 Progress: 80/10000 | Success : 80 | Errors : 0 | Rate : 100.0%
#
# Final results : 80 successfully triplets out of 80 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 81/10000 ---
# ✅ Successfully generated triplet 81
# 📊 Progress: 81/10000 | Success : 81 | Errors : 0 | Rate : 100.0%
#
# Final results : 81 successfully triplets out of 81 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 82/10000 ---
# ✅ Successfully generated triplet 82
# 📊 Progress: 82/10000 | Success : 82 | Errors : 0 | Rate : 100.0%
#
# Final results : 82 successfully triplets out of 82 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 83/10000 ---
# Rate limit reached. Waiting 29.4 seconds....
# ✅ Successfully generated triplet 83
# 📊 Progress: 83/10000 | Success : 83 | Errors : 0 | Rate : 100.0%
#
# Final results : 83 successfully triplets out of 83 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 84/10000 ---
# ✅ Successfully generated triplet 84
# 📊 Progress: 84/10000 | Success : 84 | Errors : 0 | Rate : 100.0%
#
# Final results : 84 successfully triplets out of 84 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 85/10000 ---
# ✅ Successfully generated triplet 85
# 📊 Progress: 85/10000 | Success : 85 | Errors : 0 | Rate : 100.0%
#
# Final results : 85 successfully triplets out of 85 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 86/10000 ---
# ✅ Successfully generated triplet 86
# 📊 Progress: 86/10000 | Success : 86 | Errors : 0 | Rate : 100.0%
#
# Final results : 86 successfully triplets out of 86 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 87/10000 ---
# ✅ Successfully generated triplet 87
# 📊 Progress: 87/10000 | Success : 87 | Errors : 0 | Rate : 100.0%
#
# Final results : 87 successfully triplets out of 87 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 88/10000 ---
# ✅ Successfully generated triplet 88
# 📊 Progress: 88/10000 | Success : 88 | Errors : 0 | Rate : 100.0%
#
# Final results : 88 successfully triplets out of 88 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 89/10000 ---
# ✅ Successfully generated triplet 89
# 📊 Progress: 89/10000 | Success : 89 | Errors : 0 | Rate : 100.0%
#
# Final results : 89 successfully triplets out of 89 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 90/10000 ---
# ✅ Successfully generated triplet 90
# 💾 Progress saved at 90 triplets
# 📊 Progress: 90/10000 | Success : 90 | Errors : 0 | Rate : 100.0%
#
# Final results : 90 successfully triplets out of 90 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 91/10000 ---
# ✅ Successfully generated triplet 91
# 📊 Progress: 91/10000 | Success : 91 | Errors : 0 | Rate : 100.0%
#
# Final results : 91 successfully triplets out of 91 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 92/10000 ---
# ✅ Successfully generated triplet 92
# 📊 Progress: 92/10000 | Success : 92 | Errors : 0 | Rate : 100.0%
#
# Final results : 92 successfully triplets out of 92 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 93/10000 ---
# ✅ Successfully generated triplet 93
# 📊 Progress: 93/10000 | Success : 93 | Errors : 0 | Rate : 100.0%
#
# Final results : 93 successfully triplets out of 93 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 94/10000 ---
# ✅ Successfully generated triplet 94
# 📊 Progress: 94/10000 | Success : 94 | Errors : 0 | Rate : 100.0%
#
# Final results : 94 successfully triplets out of 94 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 95/10000 ---
# Rate limit reached. Waiting 28.6 seconds....
# ✅ Successfully generated triplet 95
# 📊 Progress: 95/10000 | Success : 95 | Errors : 0 | Rate : 100.0%
#
# Final results : 95 successfully triplets out of 95 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 96/10000 ---
# ✅ Successfully generated triplet 96
# 📊 Progress: 96/10000 | Success : 96 | Errors : 0 | Rate : 100.0%
#
# Final results : 96 successfully triplets out of 96 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 97/10000 ---
# ✅ Successfully generated triplet 97
# 📊 Progress: 97/10000 | Success : 97 | Errors : 0 | Rate : 100.0%
#
# Final results : 97 successfully triplets out of 97 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 98/10000 ---
# ✅ Successfully generated triplet 98
# 📊 Progress: 98/10000 | Success : 98 | Errors : 0 | Rate : 100.0%
#
# Final results : 98 successfully triplets out of 98 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 99/10000 ---
# ✅ Successfully generated triplet 99
# 📊 Progress: 99/10000 | Success : 99 | Errors : 0 | Rate : 100.0%
#
# Final results : 99 successfully triplets out of 99 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 100/10000 ---
# Rate limit reached. Waiting 46.7 seconds....
# ✅ Successfully generated triplet 100
# 💾 Progress saved at 100 triplets
# 📊 Progress: 100/10000 | Success : 100 | Errors : 0 | Rate : 100.0%
#
# Final results : 100 successfully triplets out of 100 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 101/10000 ---
# ✅ Successfully generated triplet 101
# 📊 Progress: 101/10000 | Success : 101 | Errors : 0 | Rate : 100.0%
#
# Final results : 101 successfully triplets out of 101 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 102/10000 ---
# ✅ Successfully generated triplet 102
# 📊 Progress: 102/10000 | Success : 102 | Errors : 0 | Rate : 100.0%
#
# Final results : 102 successfully triplets out of 102 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 103/10000 ---
# ✅ Successfully generated triplet 103
# 📊 Progress: 103/10000 | Success : 103 | Errors : 0 | Rate : 100.0%
#
# Final results : 103 successfully triplets out of 103 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 104/10000 ---
# ✅ Successfully generated triplet 104
# 📊 Progress: 104/10000 | Success : 104 | Errors : 0 | Rate : 100.0%
#
# Final results : 104 successfully triplets out of 104 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 105/10000 ---
# ✅ Successfully generated triplet 105
# 📊 Progress: 105/10000 | Success : 105 | Errors : 0 | Rate : 100.0%
#
# Final results : 105 successfully triplets out of 105 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 106/10000 ---
# ✅ Successfully generated triplet 106
# 📊 Progress: 106/10000 | Success : 106 | Errors : 0 | Rate : 100.0%
#
# Final results : 106 successfully triplets out of 106 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 107/10000 ---
# ✅ Successfully generated triplet 107
# 📊 Progress: 107/10000 | Success : 107 | Errors : 0 | Rate : 100.0%
#
# Final results : 107 successfully triplets out of 107 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 108/10000 ---
# Rate limit reached. Waiting 38.9 seconds....
# ✅ Successfully generated triplet 108
# 📊 Progress: 108/10000 | Success : 108 | Errors : 0 | Rate : 100.0%
#
# Final results : 108 successfully triplets out of 108 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 109/10000 ---
# ✅ Successfully generated triplet 109
# 📊 Progress: 109/10000 | Success : 109 | Errors : 0 | Rate : 100.0%
#
# Final results : 109 successfully triplets out of 109 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 110/10000 ---
# ✅ Successfully generated triplet 110
# 💾 Progress saved at 110 triplets
# 📊 Progress: 110/10000 | Success : 110 | Errors : 0 | Rate : 100.0%
#
# Final results : 110 successfully triplets out of 110 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 111/10000 ---
# ✅ Successfully generated triplet 111
# 📊 Progress: 111/10000 | Success : 111 | Errors : 0 | Rate : 100.0%
#
# Final results : 111 successfully triplets out of 111 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 112/10000 ---
# ✅ Successfully generated triplet 112
# 📊 Progress: 112/10000 | Success : 112 | Errors : 0 | Rate : 100.0%
#
# Final results : 112 successfully triplets out of 112 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 113/10000 ---
# ✅ Successfully generated triplet 113
# 📊 Progress: 113/10000 | Success : 113 | Errors : 0 | Rate : 100.0%
#
# Final results : 113 successfully triplets out of 113 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 114/10000 ---
# ✅ Successfully generated triplet 114
# 📊 Progress: 114/10000 | Success : 114 | Errors : 0 | Rate : 100.0%
#
# Final results : 114 successfully triplets out of 114 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 115/10000 ---
# ✅ Successfully generated triplet 115
# 📊 Progress: 115/10000 | Success : 115 | Errors : 0 | Rate : 100.0%
#
# Final results : 115 successfully triplets out of 115 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 116/10000 ---
# ✅ Successfully generated triplet 116
# 📊 Progress: 116/10000 | Success : 116 | Errors : 0 | Rate : 100.0%
#
# Final results : 116 successfully triplets out of 116 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 117/10000 ---
# Rate limit reached. Waiting 33.8 seconds....
# ✅ Successfully generated triplet 117
# 📊 Progress: 117/10000 | Success : 117 | Errors : 0 | Rate : 100.0%
#
# Final results : 117 successfully triplets out of 117 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 118/10000 ---
# ✅ Successfully generated triplet 118
# 📊 Progress: 118/10000 | Success : 118 | Errors : 0 | Rate : 100.0%
#
# Final results : 118 successfully triplets out of 118 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 119/10000 ---
# ✅ Successfully generated triplet 119
# 📊 Progress: 119/10000 | Success : 119 | Errors : 0 | Rate : 100.0%
#
# Final results : 119 successfully triplets out of 119 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 120/10000 ---
# ✅ Successfully generated triplet 120
# 💾 Progress saved at 120 triplets
# 📊 Progress: 120/10000 | Success : 120 | Errors : 0 | Rate : 100.0%
#
# Final results : 120 successfully triplets out of 120 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 121/10000 ---
# ✅ Successfully generated triplet 121
# 📊 Progress: 121/10000 | Success : 121 | Errors : 0 | Rate : 100.0%
#
# Final results : 121 successfully triplets out of 121 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 122/10000 ---
# ✅ Successfully generated triplet 122
# 📊 Progress: 122/10000 | Success : 122 | Errors : 0 | Rate : 100.0%
#
# Final results : 122 successfully triplets out of 122 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 123/10000 ---
# ✅ Successfully generated triplet 123
# 📊 Progress: 123/10000 | Success : 123 | Errors : 0 | Rate : 100.0%
#
# Final results : 123 successfully triplets out of 123 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 124/10000 ---
# ✅ Successfully generated triplet 124
# 📊 Progress: 124/10000 | Success : 124 | Errors : 0 | Rate : 100.0%
#
# Final results : 124 successfully triplets out of 124 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 125/10000 ---
# ✅ Successfully generated triplet 125
# 📊 Progress: 125/10000 | Success : 125 | Errors : 0 | Rate : 100.0%
#
# Final results : 125 successfully triplets out of 125 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 126/10000 ---
# ✅ Successfully generated triplet 126
# 📊 Progress: 126/10000 | Success : 126 | Errors : 0 | Rate : 100.0%
#
# Final results : 126 successfully triplets out of 126 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 127/10000 ---
# ✅ Successfully generated triplet 127
# 📊 Progress: 127/10000 | Success : 127 | Errors : 0 | Rate : 100.0%
#
# Final results : 127 successfully triplets out of 127 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 128/10000 ---
# Rate limit reached. Waiting 30.3 seconds....
# ✅ Successfully generated triplet 128
# 📊 Progress: 128/10000 | Success : 128 | Errors : 0 | Rate : 100.0%
#
# Final results : 128 successfully triplets out of 128 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 129/10000 ---
# ✅ Successfully generated triplet 129
# 📊 Progress: 129/10000 | Success : 129 | Errors : 0 | Rate : 100.0%
#
# Final results : 129 successfully triplets out of 129 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 130/10000 ---
# ✅ Successfully generated triplet 130
# 💾 Progress saved at 130 triplets
# 📊 Progress: 130/10000 | Success : 130 | Errors : 0 | Rate : 100.0%
#
# Final results : 130 successfully triplets out of 130 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 131/10000 ---
# ✅ Successfully generated triplet 131
# 📊 Progress: 131/10000 | Success : 131 | Errors : 0 | Rate : 100.0%
#
# Final results : 131 successfully triplets out of 131 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 132/10000 ---
# ✅ Successfully generated triplet 132
# 📊 Progress: 132/10000 | Success : 132 | Errors : 0 | Rate : 100.0%
#
# Final results : 132 successfully triplets out of 132 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 133/10000 ---
# ✅ Successfully generated triplet 133
# 📊 Progress: 133/10000 | Success : 133 | Errors : 0 | Rate : 100.0%
#
# Final results : 133 successfully triplets out of 133 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 134/10000 ---
# ✅ Successfully generated triplet 134
# 📊 Progress: 134/10000 | Success : 134 | Errors : 0 | Rate : 100.0%
#
# Final results : 134 successfully triplets out of 134 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 135/10000 ---
# ✅ Successfully generated triplet 135
# 📊 Progress: 135/10000 | Success : 135 | Errors : 0 | Rate : 100.0%
#
# Final results : 135 successfully triplets out of 135 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 136/10000 ---
# ✅ Successfully generated triplet 136
# 📊 Progress: 136/10000 | Success : 136 | Errors : 0 | Rate : 100.0%
#
# Final results : 136 successfully triplets out of 136 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 137/10000 ---
# ✅ Successfully generated triplet 137
# 📊 Progress: 137/10000 | Success : 137 | Errors : 0 | Rate : 100.0%
#
# Final results : 137 successfully triplets out of 137 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 138/10000 ---
# ✅ Successfully generated triplet 138
# 📊 Progress: 138/10000 | Success : 138 | Errors : 0 | Rate : 100.0%
#
# Final results : 138 successfully triplets out of 138 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 139/10000 ---
# ✅ Successfully generated triplet 139
# 📊 Progress: 139/10000 | Success : 139 | Errors : 0 | Rate : 100.0%
#
# Final results : 139 successfully triplets out of 139 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 140/10000 ---
# ✅ Successfully generated triplet 140
# 💾 Progress saved at 140 triplets
# 📊 Progress: 140/10000 | Success : 140 | Errors : 0 | Rate : 100.0%
#
# Final results : 140 successfully triplets out of 140 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 141/10000 ---
# Rate limit reached. Waiting 25.9 seconds....
# ✅ Successfully generated triplet 141
# 📊 Progress: 141/10000 | Success : 141 | Errors : 0 | Rate : 100.0%
#
# Final results : 141 successfully triplets out of 141 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 142/10000 ---
# ✅ Successfully generated triplet 142
# 📊 Progress: 142/10000 | Success : 142 | Errors : 0 | Rate : 100.0%
#
# Final results : 142 successfully triplets out of 142 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 143/10000 ---
# ✅ Successfully generated triplet 143
# 📊 Progress: 143/10000 | Success : 143 | Errors : 0 | Rate : 100.0%
#
# Final results : 143 successfully triplets out of 143 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 144/10000 ---
# ✅ Successfully generated triplet 144
# 📊 Progress: 144/10000 | Success : 144 | Errors : 0 | Rate : 100.0%
#
# Final results : 144 successfully triplets out of 144 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 145/10000 ---
# ✅ Successfully generated triplet 145
# 📊 Progress: 145/10000 | Success : 145 | Errors : 0 | Rate : 100.0%
#
# Final results : 145 successfully triplets out of 145 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 146/10000 ---
# ✅ Successfully generated triplet 146
# 📊 Progress: 146/10000 | Success : 146 | Errors : 0 | Rate : 100.0%
#
# Final results : 146 successfully triplets out of 146 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 147/10000 ---
# ✅ Successfully generated triplet 147
# 📊 Progress: 147/10000 | Success : 147 | Errors : 0 | Rate : 100.0%
#
# Final results : 147 successfully triplets out of 147 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 148/10000 ---
# ✅ Successfully generated triplet 148
# 📊 Progress: 148/10000 | Success : 148 | Errors : 0 | Rate : 100.0%
#
# Final results : 148 successfully triplets out of 148 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 149/10000 ---
# ✅ Successfully generated triplet 149
# 📊 Progress: 149/10000 | Success : 149 | Errors : 0 | Rate : 100.0%
#
# Final results : 149 successfully triplets out of 149 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 150/10000 ---
# ✅ Successfully generated triplet 150
# 💾 Progress saved at 150 triplets
# 📊 Progress: 150/10000 | Success : 150 | Errors : 0 | Rate : 100.0%
#
# Final results : 150 successfully triplets out of 150 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 151/10000 ---
# Rate limit reached. Waiting 33.6 seconds....
# ✅ Successfully generated triplet 151
# 📊 Progress: 151/10000 | Success : 151 | Errors : 0 | Rate : 100.0%
#
# Final results : 151 successfully triplets out of 151 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 152/10000 ---
# ✅ Successfully generated triplet 152
# 📊 Progress: 152/10000 | Success : 152 | Errors : 0 | Rate : 100.0%
#
# Final results : 152 successfully triplets out of 152 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 153/10000 ---
# ✅ Successfully generated triplet 153
# 📊 Progress: 153/10000 | Success : 153 | Errors : 0 | Rate : 100.0%
#
# Final results : 153 successfully triplets out of 153 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 154/10000 ---
# ✅ Successfully generated triplet 154
# 📊 Progress: 154/10000 | Success : 154 | Errors : 0 | Rate : 100.0%
#
# Final results : 154 successfully triplets out of 154 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 155/10000 ---
# ✅ Successfully generated triplet 155
# 📊 Progress: 155/10000 | Success : 155 | Errors : 0 | Rate : 100.0%
#
# Final results : 155 successfully triplets out of 155 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 156/10000 ---
# ✅ Successfully generated triplet 156
# 📊 Progress: 156/10000 | Success : 156 | Errors : 0 | Rate : 100.0%
#
# Final results : 156 successfully triplets out of 156 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 157/10000 ---
# ✅ Successfully generated triplet 157
# 📊 Progress: 157/10000 | Success : 157 | Errors : 0 | Rate : 100.0%
#
# Final results : 157 successfully triplets out of 157 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 158/10000 ---
# ✅ Successfully generated triplet 158
# 📊 Progress: 158/10000 | Success : 158 | Errors : 0 | Rate : 100.0%
#
# Final results : 158 successfully triplets out of 158 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 159/10000 ---
# ✅ Successfully generated triplet 159
# 📊 Progress: 159/10000 | Success : 159 | Errors : 0 | Rate : 100.0%
#
# Final results : 159 successfully triplets out of 159 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 160/10000 ---
# ✅ Successfully generated triplet 160
# 💾 Progress saved at 160 triplets
# 📊 Progress: 160/10000 | Success : 160 | Errors : 0 | Rate : 100.0%
#
# Final results : 160 successfully triplets out of 160 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 161/10000 ---
# ✅ Successfully generated triplet 161
# 📊 Progress: 161/10000 | Success : 161 | Errors : 0 | Rate : 100.0%
#
# Final results : 161 successfully triplets out of 161 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 162/10000 ---
# ✅ Successfully generated triplet 162
# 📊 Progress: 162/10000 | Success : 162 | Errors : 0 | Rate : 100.0%
#
# Final results : 162 successfully triplets out of 162 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 163/10000 ---
# Rate limit reached. Waiting 27.9 seconds....
# ✅ Successfully generated triplet 163
# 📊 Progress: 163/10000 | Success : 163 | Errors : 0 | Rate : 100.0%
#
# Final results : 163 successfully triplets out of 163 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 164/10000 ---
# ✅ Successfully generated triplet 164
# 📊 Progress: 164/10000 | Success : 164 | Errors : 0 | Rate : 100.0%
#
# Final results : 164 successfully triplets out of 164 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 165/10000 ---
# ✅ Successfully generated triplet 165
# 📊 Progress: 165/10000 | Success : 165 | Errors : 0 | Rate : 100.0%
#
# Final results : 165 successfully triplets out of 165 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 166/10000 ---
# ✅ Successfully generated triplet 166
# 📊 Progress: 166/10000 | Success : 166 | Errors : 0 | Rate : 100.0%
#
# Final results : 166 successfully triplets out of 166 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 167/10000 ---
# ✅ Successfully generated triplet 167
# 📊 Progress: 167/10000 | Success : 167 | Errors : 0 | Rate : 100.0%
#
# Final results : 167 successfully triplets out of 167 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 168/10000 ---
# ✅ Successfully generated triplet 168
# 📊 Progress: 168/10000 | Success : 168 | Errors : 0 | Rate : 100.0%
#
# Final results : 168 successfully triplets out of 168 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 169/10000 ---
# ✅ Successfully generated triplet 169
# 📊 Progress: 169/10000 | Success : 169 | Errors : 0 | Rate : 100.0%
#
# Final results : 169 successfully triplets out of 169 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 170/10000 ---
# ✅ Successfully generated triplet 170
# 💾 Progress saved at 170 triplets
# 📊 Progress: 170/10000 | Success : 170 | Errors : 0 | Rate : 100.0%
#
# Final results : 170 successfully triplets out of 170 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 171/10000 ---
# ✅ Successfully generated triplet 171
# 📊 Progress: 171/10000 | Success : 171 | Errors : 0 | Rate : 100.0%
#
# Final results : 171 successfully triplets out of 171 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 172/10000 ---
# ✅ Successfully generated triplet 172
# 📊 Progress: 172/10000 | Success : 172 | Errors : 0 | Rate : 100.0%
#
# Final results : 172 successfully triplets out of 172 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 173/10000 ---
# ✅ Successfully generated triplet 173
# 📊 Progress: 173/10000 | Success : 173 | Errors : 0 | Rate : 100.0%
#
# Final results : 173 successfully triplets out of 173 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 174/10000 ---
# Rate limit reached. Waiting 29.6 seconds....
# ✅ Successfully generated triplet 174
# 📊 Progress: 174/10000 | Success : 174 | Errors : 0 | Rate : 100.0%
#
# Final results : 174 successfully triplets out of 174 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 175/10000 ---
# ✅ Successfully generated triplet 175
# 📊 Progress: 175/10000 | Success : 175 | Errors : 0 | Rate : 100.0%
#
# Final results : 175 successfully triplets out of 175 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 176/10000 ---
# ✅ Successfully generated triplet 176
# 📊 Progress: 176/10000 | Success : 176 | Errors : 0 | Rate : 100.0%
#
# Final results : 176 successfully triplets out of 176 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 177/10000 ---
# ✅ Successfully generated triplet 177
# 📊 Progress: 177/10000 | Success : 177 | Errors : 0 | Rate : 100.0%
#
# Final results : 177 successfully triplets out of 177 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 178/10000 ---
# ✅ Successfully generated triplet 178
# 📊 Progress: 178/10000 | Success : 178 | Errors : 0 | Rate : 100.0%
#
# Final results : 178 successfully triplets out of 178 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 179/10000 ---
# ✅ Successfully generated triplet 179
# 📊 Progress: 179/10000 | Success : 179 | Errors : 0 | Rate : 100.0%
#
# Final results : 179 successfully triplets out of 179 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 180/10000 ---
# ✅ Successfully generated triplet 180
# 💾 Progress saved at 180 triplets
# 📊 Progress: 180/10000 | Success : 180 | Errors : 0 | Rate : 100.0%
#
# Final results : 180 successfully triplets out of 180 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 181/10000 ---
# ✅ Successfully generated triplet 181
# 📊 Progress: 181/10000 | Success : 181 | Errors : 0 | Rate : 100.0%
#
# Final results : 181 successfully triplets out of 181 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 182/10000 ---
# ✅ Successfully generated triplet 182
# 📊 Progress: 182/10000 | Success : 182 | Errors : 0 | Rate : 100.0%
#
# Final results : 182 successfully triplets out of 182 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 183/10000 ---
# Rate limit reached. Waiting 34.3 seconds....
# ✅ Successfully generated triplet 183
# 📊 Progress: 183/10000 | Success : 183 | Errors : 0 | Rate : 100.0%
#
# Final results : 183 successfully triplets out of 183 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 184/10000 ---
# ✅ Successfully generated triplet 184
# 📊 Progress: 184/10000 | Success : 184 | Errors : 0 | Rate : 100.0%
#
# Final results : 184 successfully triplets out of 184 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 185/10000 ---
# ✅ Successfully generated triplet 185
# 📊 Progress: 185/10000 | Success : 185 | Errors : 0 | Rate : 100.0%
#
# Final results : 185 successfully triplets out of 185 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 186/10000 ---
# ✅ Successfully generated triplet 186
# 📊 Progress: 186/10000 | Success : 186 | Errors : 0 | Rate : 100.0%
#
# Final results : 186 successfully triplets out of 186 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 187/10000 ---
# ✅ Successfully generated triplet 187
# 📊 Progress: 187/10000 | Success : 187 | Errors : 0 | Rate : 100.0%
#
# Final results : 187 successfully triplets out of 187 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 188/10000 ---
# ✅ Successfully generated triplet 188
# 📊 Progress: 188/10000 | Success : 188 | Errors : 0 | Rate : 100.0%
#
# Final results : 188 successfully triplets out of 188 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 189/10000 ---
# ✅ Successfully generated triplet 189
# 📊 Progress: 189/10000 | Success : 189 | Errors : 0 | Rate : 100.0%
#
# Final results : 189 successfully triplets out of 189 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 190/10000 ---
# ✅ Successfully generated triplet 190
# 💾 Progress saved at 190 triplets
# 📊 Progress: 190/10000 | Success : 190 | Errors : 0 | Rate : 100.0%
#
# Final results : 190 successfully triplets out of 190 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 191/10000 ---
# ✅ Successfully generated triplet 191
# 📊 Progress: 191/10000 | Success : 191 | Errors : 0 | Rate : 100.0%
#
# Final results : 191 successfully triplets out of 191 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 192/10000 ---
# ✅ Successfully generated triplet 192
# 📊 Progress: 192/10000 | Success : 192 | Errors : 0 | Rate : 100.0%
#
# Final results : 192 successfully triplets out of 192 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 193/10000 ---
# ✅ Successfully generated triplet 193
# 📊 Progress: 193/10000 | Success : 193 | Errors : 0 | Rate : 100.0%
#
# Final results : 193 successfully triplets out of 193 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 194/10000 ---
# ✅ Successfully generated triplet 194
# 📊 Progress: 194/10000 | Success : 194 | Errors : 0 | Rate : 100.0%
#
# Final results : 194 successfully triplets out of 194 attempts
# Total errors : 0
# Success rate: 100.0%
#
# --- Processing content 195/10000 ---
# ...
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9939/10000 ---
# ✅ Successfully generated triplet 9925
# 📊 Progress: 9939/10000 | Success : 9925 | Errors : 14 | Rate : 99.9%
#
# Final results : 9925 successfully triplets out of 9939 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9940/10000 ---
# Rate limit reached. Waiting 27.1 seconds....
# ✅ Successfully generated triplet 9926
# 📊 Progress: 9940/10000 | Success : 9926 | Errors : 14 | Rate : 99.9%
#
# Final results : 9926 successfully triplets out of 9940 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9941/10000 ---
# ✅ Successfully generated triplet 9927
# 📊 Progress: 9941/10000 | Success : 9927 | Errors : 14 | Rate : 99.9%
#
# Final results : 9927 successfully triplets out of 9941 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9942/10000 ---
# ✅ Successfully generated triplet 9928
# 📊 Progress: 9942/10000 | Success : 9928 | Errors : 14 | Rate : 99.9%
#
# Final results : 9928 successfully triplets out of 9942 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9943/10000 ---
# ✅ Successfully generated triplet 9929
# 📊 Progress: 9943/10000 | Success : 9929 | Errors : 14 | Rate : 99.9%
#
# Final results : 9929 successfully triplets out of 9943 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9944/10000 ---
# ✅ Successfully generated triplet 9930
# 💾 Progress saved at 9930 triplets
# 📊 Progress: 9944/10000 | Success : 9930 | Errors : 14 | Rate : 99.9%
#
# Final results : 9930 successfully triplets out of 9944 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9945/10000 ---
# ✅ Successfully generated triplet 9931
# 📊 Progress: 9945/10000 | Success : 9931 | Errors : 14 | Rate : 99.9%
#
# Final results : 9931 successfully triplets out of 9945 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9946/10000 ---
# ✅ Successfully generated triplet 9932
# 📊 Progress: 9946/10000 | Success : 9932 | Errors : 14 | Rate : 99.9%
#
# Final results : 9932 successfully triplets out of 9946 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9947/10000 ---
# Rate limit reached. Waiting 38.5 seconds....
# ✅ Successfully generated triplet 9933
# 📊 Progress: 9947/10000 | Success : 9933 | Errors : 14 | Rate : 99.9%
#
# Final results : 9933 successfully triplets out of 9947 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9948/10000 ---
# ✅ Successfully generated triplet 9934
# 📊 Progress: 9948/10000 | Success : 9934 | Errors : 14 | Rate : 99.9%
#
# Final results : 9934 successfully triplets out of 9948 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9949/10000 ---
# ✅ Successfully generated triplet 9935
# 📊 Progress: 9949/10000 | Success : 9935 | Errors : 14 | Rate : 99.9%
#
# Final results : 9935 successfully triplets out of 9949 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9950/10000 ---
# ✅ Successfully generated triplet 9936
# 📊 Progress: 9950/10000 | Success : 9936 | Errors : 14 | Rate : 99.9%
#
# Final results : 9936 successfully triplets out of 9950 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9951/10000 ---
# ✅ Successfully generated triplet 9937
# 📊 Progress: 9951/10000 | Success : 9937 | Errors : 14 | Rate : 99.9%
#
# Final results : 9937 successfully triplets out of 9951 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9952/10000 ---
# ✅ Successfully generated triplet 9938
# 📊 Progress: 9952/10000 | Success : 9938 | Errors : 14 | Rate : 99.9%
#
# Final results : 9938 successfully triplets out of 9952 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9953/10000 ---
# ✅ Successfully generated triplet 9939
# 📊 Progress: 9953/10000 | Success : 9939 | Errors : 14 | Rate : 99.9%
#
# Final results : 9939 successfully triplets out of 9953 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9954/10000 ---
# ✅ Successfully generated triplet 9940
# 💾 Progress saved at 9940 triplets
# 📊 Progress: 9954/10000 | Success : 9940 | Errors : 14 | Rate : 99.9%
#
# Final results : 9940 successfully triplets out of 9954 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9955/10000 ---
# ✅ Successfully generated triplet 9941
# 📊 Progress: 9955/10000 | Success : 9941 | Errors : 14 | Rate : 99.9%
#
# Final results : 9941 successfully triplets out of 9955 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9956/10000 ---
# Rate limit reached. Waiting 35.9 seconds....
# ✅ Successfully generated triplet 9942
# 📊 Progress: 9956/10000 | Success : 9942 | Errors : 14 | Rate : 99.9%
#
# Final results : 9942 successfully triplets out of 9956 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9957/10000 ---
# ✅ Successfully generated triplet 9943
# 📊 Progress: 9957/10000 | Success : 9943 | Errors : 14 | Rate : 99.9%
#
# Final results : 9943 successfully triplets out of 9957 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9958/10000 ---
# ✅ Successfully generated triplet 9944
# 📊 Progress: 9958/10000 | Success : 9944 | Errors : 14 | Rate : 99.9%
#
# Final results : 9944 successfully triplets out of 9958 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9959/10000 ---
# ✅ Successfully generated triplet 9945
# 📊 Progress: 9959/10000 | Success : 9945 | Errors : 14 | Rate : 99.9%
#
# Final results : 9945 successfully triplets out of 9959 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9960/10000 ---
# ✅ Successfully generated triplet 9946
# 📊 Progress: 9960/10000 | Success : 9946 | Errors : 14 | Rate : 99.9%
#
# Final results : 9946 successfully triplets out of 9960 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9961/10000 ---
# ✅ Successfully generated triplet 9947
# 📊 Progress: 9961/10000 | Success : 9947 | Errors : 14 | Rate : 99.9%
#
# Final results : 9947 successfully triplets out of 9961 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9962/10000 ---
# ✅ Successfully generated triplet 9948
# 📊 Progress: 9962/10000 | Success : 9948 | Errors : 14 | Rate : 99.9%
#
# Final results : 9948 successfully triplets out of 9962 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9963/10000 ---
# ✅ Successfully generated triplet 9949
# 📊 Progress: 9963/10000 | Success : 9949 | Errors : 14 | Rate : 99.9%
#
# Final results : 9949 successfully triplets out of 9963 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9964/10000 ---
# ✅ Successfully generated triplet 9950
# 💾 Progress saved at 9950 triplets
# 📊 Progress: 9964/10000 | Success : 9950 | Errors : 14 | Rate : 99.9%
#
# Final results : 9950 successfully triplets out of 9964 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9965/10000 ---
# Rate limit reached. Waiting 34.8 seconds....
# ✅ Successfully generated triplet 9951
# 📊 Progress: 9965/10000 | Success : 9951 | Errors : 14 | Rate : 99.9%
#
# Final results : 9951 successfully triplets out of 9965 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9966/10000 ---
# ✅ Successfully generated triplet 9952
# 📊 Progress: 9966/10000 | Success : 9952 | Errors : 14 | Rate : 99.9%
#
# Final results : 9952 successfully triplets out of 9966 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9967/10000 ---
# ✅ Successfully generated triplet 9953
# 📊 Progress: 9967/10000 | Success : 9953 | Errors : 14 | Rate : 99.9%
#
# Final results : 9953 successfully triplets out of 9967 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9968/10000 ---
# ✅ Successfully generated triplet 9954
# 📊 Progress: 9968/10000 | Success : 9954 | Errors : 14 | Rate : 99.9%
#
# Final results : 9954 successfully triplets out of 9968 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9969/10000 ---
# ✅ Successfully generated triplet 9955
# 📊 Progress: 9969/10000 | Success : 9955 | Errors : 14 | Rate : 99.9%
#
# Final results : 9955 successfully triplets out of 9969 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9970/10000 ---
# ✅ Successfully generated triplet 9956
# 📊 Progress: 9970/10000 | Success : 9956 | Errors : 14 | Rate : 99.9%
#
# Final results : 9956 successfully triplets out of 9970 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9971/10000 ---
# ✅ Successfully generated triplet 9957
# 📊 Progress: 9971/10000 | Success : 9957 | Errors : 14 | Rate : 99.9%
#
# Final results : 9957 successfully triplets out of 9971 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9972/10000 ---
# ✅ Successfully generated triplet 9958
# 📊 Progress: 9972/10000 | Success : 9958 | Errors : 14 | Rate : 99.9%
#
# Final results : 9958 successfully triplets out of 9972 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9973/10000 ---
# ✅ Successfully generated triplet 9959
# 📊 Progress: 9973/10000 | Success : 9959 | Errors : 14 | Rate : 99.9%
#
# Final results : 9959 successfully triplets out of 9973 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9974/10000 ---
# ✅ Successfully generated triplet 9960
# 💾 Progress saved at 9960 triplets
# 📊 Progress: 9974/10000 | Success : 9960 | Errors : 14 | Rate : 99.9%
#
# Final results : 9960 successfully triplets out of 9974 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9975/10000 ---
# ✅ Successfully generated triplet 9961
# 📊 Progress: 9975/10000 | Success : 9961 | Errors : 14 | Rate : 99.9%
#
# Final results : 9961 successfully triplets out of 9975 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9976/10000 ---
# Rate limit reached. Waiting 29.2 seconds....
# ✅ Successfully generated triplet 9962
# 📊 Progress: 9976/10000 | Success : 9962 | Errors : 14 | Rate : 99.9%
#
# Final results : 9962 successfully triplets out of 9976 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9977/10000 ---
# ✅ Successfully generated triplet 9963
# 📊 Progress: 9977/10000 | Success : 9963 | Errors : 14 | Rate : 99.9%
#
# Final results : 9963 successfully triplets out of 9977 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9978/10000 ---
# ✅ Successfully generated triplet 9964
# 📊 Progress: 9978/10000 | Success : 9964 | Errors : 14 | Rate : 99.9%
#
# Final results : 9964 successfully triplets out of 9978 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9979/10000 ---
# ✅ Successfully generated triplet 9965
# 📊 Progress: 9979/10000 | Success : 9965 | Errors : 14 | Rate : 99.9%
#
# Final results : 9965 successfully triplets out of 9979 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9980/10000 ---
# ✅ Successfully generated triplet 9966
# 📊 Progress: 9980/10000 | Success : 9966 | Errors : 14 | Rate : 99.9%
#
# Final results : 9966 successfully triplets out of 9980 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9981/10000 ---
# ✅ Successfully generated triplet 9967
# 📊 Progress: 9981/10000 | Success : 9967 | Errors : 14 | Rate : 99.9%
#
# Final results : 9967 successfully triplets out of 9981 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9982/10000 ---
# ✅ Successfully generated triplet 9968
# 📊 Progress: 9982/10000 | Success : 9968 | Errors : 14 | Rate : 99.9%
#
# Final results : 9968 successfully triplets out of 9982 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9983/10000 ---
# ✅ Successfully generated triplet 9969
# 📊 Progress: 9983/10000 | Success : 9969 | Errors : 14 | Rate : 99.9%
#
# Final results : 9969 successfully triplets out of 9983 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9984/10000 ---
# ✅ Successfully generated triplet 9970
# 💾 Progress saved at 9970 triplets
# 📊 Progress: 9984/10000 | Success : 9970 | Errors : 14 | Rate : 99.9%
#
# Final results : 9970 successfully triplets out of 9984 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9985/10000 ---
# ✅ Successfully generated triplet 9971
# 📊 Progress: 9985/10000 | Success : 9971 | Errors : 14 | Rate : 99.9%
#
# Final results : 9971 successfully triplets out of 9985 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9986/10000 ---
# ✅ Successfully generated triplet 9972
# 📊 Progress: 9986/10000 | Success : 9972 | Errors : 14 | Rate : 99.9%
#
# Final results : 9972 successfully triplets out of 9986 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9987/10000 ---
# Rate limit reached. Waiting 28.5 seconds....
# ✅ Successfully generated triplet 9973
# 📊 Progress: 9987/10000 | Success : 9973 | Errors : 14 | Rate : 99.9%
#
# Final results : 9973 successfully triplets out of 9987 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9988/10000 ---
# ✅ Successfully generated triplet 9974
# 📊 Progress: 9988/10000 | Success : 9974 | Errors : 14 | Rate : 99.9%
#
# Final results : 9974 successfully triplets out of 9988 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9989/10000 ---
# ✅ Successfully generated triplet 9975
# 📊 Progress: 9989/10000 | Success : 9975 | Errors : 14 | Rate : 99.9%
#
# Final results : 9975 successfully triplets out of 9989 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9990/10000 ---
# ✅ Successfully generated triplet 9976
# 📊 Progress: 9990/10000 | Success : 9976 | Errors : 14 | Rate : 99.9%
#
# Final results : 9976 successfully triplets out of 9990 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9991/10000 ---
# ✅ Successfully generated triplet 9977
# 📊 Progress: 9991/10000 | Success : 9977 | Errors : 14 | Rate : 99.9%
#
# Final results : 9977 successfully triplets out of 9991 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9992/10000 ---
# ✅ Successfully generated triplet 9978
# 📊 Progress: 9992/10000 | Success : 9978 | Errors : 14 | Rate : 99.9%
#
# Final results : 9978 successfully triplets out of 9992 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9993/10000 ---
# ✅ Successfully generated triplet 9979
# 📊 Progress: 9993/10000 | Success : 9979 | Errors : 14 | Rate : 99.9%
#
# Final results : 9979 successfully triplets out of 9993 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9994/10000 ---
# ✅ Successfully generated triplet 9980
# 💾 Progress saved at 9980 triplets
# 📊 Progress: 9994/10000 | Success : 9980 | Errors : 14 | Rate : 99.9%
#
# Final results : 9980 successfully triplets out of 9994 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9995/10000 ---
# ✅ Successfully generated triplet 9981
# 📊 Progress: 9995/10000 | Success : 9981 | Errors : 14 | Rate : 99.9%
#
# Final results : 9981 successfully triplets out of 9995 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9996/10000 ---
# ✅ Successfully generated triplet 9982
# 📊 Progress: 9996/10000 | Success : 9982 | Errors : 14 | Rate : 99.9%
#
# Final results : 9982 successfully triplets out of 9996 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9997/10000 ---
# ✅ Successfully generated triplet 9983
# 📊 Progress: 9997/10000 | Success : 9983 | Errors : 14 | Rate : 99.9%
#
# Final results : 9983 successfully triplets out of 9997 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9998/10000 ---
# Rate limit reached. Waiting 26.5 seconds....
# ✅ Successfully generated triplet 9984
# 📊 Progress: 9998/10000 | Success : 9984 | Errors : 14 | Rate : 99.9%
#
# Final results : 9984 successfully triplets out of 9998 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 9999/10000 ---
# ✅ Successfully generated triplet 9985
# 📊 Progress: 9999/10000 | Success : 9985 | Errors : 14 | Rate : 99.9%
#
# Final results : 9985 successfully triplets out of 9999 attempts
# Total errors : 14
# Success rate: 99.9%
#
# --- Processing content 10000/10000 ---
# ✅ Successfully generated triplet 9986
# 📊 Progress: 10000/10000 | Success : 9986 | Errors : 14 | Rate : 99.9%
#
# Final results : 9986 successfully triplets out of 10000 attempts
# Total errors : 14
# Success rate: 99.9%
