# %%
import pandas as pd
import json
import uuid

# %%
def load_jsonl_safely(filepath):
    data = []
    bad_lines = 0

    with open(filepath, "r", encoding="utf-8") as f:
        for i, line in enumerate(f, 1):
            line = line.strip()
            if not line:
                continue  # Skip empty lines
            try:
                obj = json.loads(line)
                data.append(obj)
            except json.JSONDecodeError:
                print(f"❌ Skipping invalid JSON on line {i}: {line[:100]}...")
                bad_lines += 1

    print(f"✅ Loaded {len(data)} valid records. Skipped {bad_lines} bad lines.")
    return pd.DataFrame(data)

# Load your file
df = load_jsonl_safely("Content/all_canada_rag_content.jsonl")

# Now you can use it
print(df.head())
print(f"Shape: {df.shape}")
# Out:
# ✅ Loaded 103552 valid records. Skipped 0 bad lines.
#                      id                                                url  \
# 0  Alberta_1_1757152647  https://www.alberta.ca/careers-fisheries-manag...
# 1  Alberta_2_1757152647  https://www.alberta.ca/carrier-profiles-and-mo...
# 2  Alberta_3_1757152647     https://www.alberta.ca/careers-land-management
# 3  Alberta_4_1757152648  https://www.alberta.ca/careers-wildlife-manage...
# 4  Alberta_5_1757152648            https://www.alberta.ca/careers-agrology
#
#                                           title  \
# 0   Careers – Fisheries management | Alberta.ca
# 1  Carrier profiles and monitoring | Alberta.ca
# 2        Careers – Land management | Alberta.ca
# 3    Careers – Wildlife management | Alberta.ca
# 4               Careers – Agrology | Alberta.ca
#
#                                          description  \
# 0  A career in fisheries management offers many o...
# 1  Supports carriers' internal monitoring of on-r...
# 2  There are many rewarding career paths for land...
# 3  A career in wildlife management offers opportu...
# 4  Agrologists can find meaningful work managing ...
#
#                                              content province     timestamp  \
# 0  A career in fisheries management offers many o...  Alberta  1.757153e+09
# 1  \n\n\n\n  * Effective December 2020, the Roads...  Alberta  1.757153e+09
# 2  The Lands Division is responsible for providin...  Alberta  1.757153e+09
# 3  A career in Wildlife Management offers a contr...  Alberta  1.757153e+09
# 4  Consider a career that enables you to make a d...  Alberta  1.757153e+09
#
#    content_length language      source document_type
# 0            4794       fr  canada_gov          html
# 1            5891       fr  canada_gov          html
# 2            6423       fr  canada_gov          html
# 3            3919       fr  canada_gov          html
# 4            4653       fr  canada_gov          html
# Shape: (103552, 11)

# %%
df.sample(3)
# Out:
#                                      id  \
# 68973           Ontario_1329_1757168643
# 13325  British_Columbia_7808_1757142579
# 34316             Canada_281_1758455948
#
#                                                      url  \
# 68973  https://www.ontario.ca/document/policy-directi...
# 13325  https://www2.gov.bc.ca/gov/content/industry/ra...
# 34316                     http://canada.ca/en/index.html
#
#                                                   title  \
# 68973                             Government of Ontario
# 13325  Wildfire recovery - Province of British Columbia
# 34316                                  Home - Canada.ca
#
#                                              description  \
# 68973                                               None
# 13325  Wildfires have damaged range lands, recovery i...
# 34316
#
#                                                  content          province  \
# 68973  We’re receiving a higher volume of requests fr...           Ontario
# 13325  Wildfire recovery efforts in the Cariboo Regio...  British_Columbia
# 34316  Canada.ca\n\nThe official website of the Gover...            Canada
#
#           timestamp  content_length language      source document_type
# 68973  1.757169e+09             611       fr  canada_gov          html
# 13325  1.757143e+09             832       fr  canada_gov          html
# 34316  1.758456e+09            1920       en  canada_gov           NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103552 entries, 0 to 103551
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              103552 non-null  object
#  1   url             103552 non-null  object
#  2   title           102903 non-null  object
#  3   description     71669 non-null   object
#  4   content         103552 non-null  object
#  5   province        103552 non-null  object
#  6   timestamp       103552 non-null  float64
#  7   content_length  103552 non-null  int64
#  8   language        103552 non-null  object
#  9   source          103552 non-null  object
#  10  document_type   88703 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 8.7+ MB

# %%
df1 =  df.drop_duplicates(subset=['url'])

# %%
canada_df = df1[df1['id'].str.contains('Canada', case=False)]

# %%
canada_df.reset_index(inplace=True)

# %%
canada_df
# Out:
#        index                      id  \
# 0      15436     Canada_5_1758454485
# 1      15437     Canada_1_1758454485
# 2      15438     Canada_2_1758454485
# 3      15439     Canada_3_1758454485
# 4      15440     Canada_9_1758454487
# ...      ...                     ...
# 25866  43896  Canada_8171_1758479609
# 25867  43897  Canada_8173_1758479609
# 25868  43898  Canada_8180_1758479610
# 25869  43900  Canada_8181_1758479616
# 25870  43901  Canada_8183_1758479617
#
#                                                      url  \
# 0      https://www.canada.ca/aboutgov-ausujetgouv/dep...
# 1                                 https://www.canada.ca/
# 2                                      http://canada.ca/
# 3        https://www.canada.ca/?ref=university.heavnn.io
# 4                         https://canada.ca/accueil.html
# ...                                                  ...
# 25866  https://www.canada.ca/fr/ministere-defense-nat...
# 25867                      https://ncc-ccn.gc.ca/podcast
# 25868  https://www.guichetemplois.gc.ca/analyse-tenda...
# 25869  https://tc.canada.ca/en/aviation/reference-cen...
# 25870  https://www.nserc-crsng.gc.ca/InterAgency-Inte...
#
#                                                    title description  \
# 0                   Departments and agencies - Canada.ca
# 1                                              Canada.ca
# 2                                              Canada.ca
# 3                                              Canada.ca
# 4                                    Accueil - Canada.ca
# ...                                                  ...         ...
# 25866  Manuel sur la politique des congés des Forces ...
# 25867  Capital Stories: An NCC podcast series | Natio...
# 25868  Explorer le marché du travail au Canada - Guic...
# 25869                 Advisory Circular (AC) No. 302-015
# 25870  NSERC - Inter-Agency, Tri-Agency Financial Adm...
#
#                                                  content province  \
# 0      Departments and agencies\n\nEnter a department...   Canada
# 1      Canada.ca\n/ Gouvernement du Canada\nGovernmen...   Canada
# 2      Canada.ca\n/ Gouvernement du Canada\nGovernmen...   Canada
# 3      Canada.ca\n/ Gouvernement du Canada\nGovernmen...   Canada
# 4      Canada.ca\n\nLe site officiel du gouvernement ...   Canada
# ...                                                  ...      ...
# 25866  Manuel de la politique des congés des Forces c...   Canada
# 25867  You are here: Home Capital Stories: An NCC pod...   Canada
# 25868  Explorer le marché du travail au Canada\n\nAcc...   Canada
# 25869  Advisory Circular (AC) No. 302-015\n\nFrom: Tr...   Canada
# 25870  Tri-agency financial administration\nSummary o...   Canada
#
#           timestamp  content_length language      source document_type
# 0      1.758454e+09            8452       en  canada_gov          html
# 1      1.758454e+09             160       en  canada_gov          html
# 2      1.758454e+09             160       en  canada_gov          html
# 3      1.758454e+09             160       en  canada_gov          html
# 4      1.758454e+09            2294       en  canada_gov          html
# ...             ...             ...      ...         ...           ...
# 25866  1.758480e+09             298       fr  canada_gov           NaN
# 25867  1.758480e+09            3616       en  canada_gov           NaN
# 25868  1.758480e+09            1323       en  canada_gov           NaN
# 25869  1.758480e+09           12621       en  canada_gov           NaN
# 25870  1.758480e+09            3301       en  canada_gov           NaN
#
# [25871 rows x 12 columns]

# %%
canada_df = canada_df.drop(["index"], axis=1)

# %%
canada_df
# Out:
#                            id  \
# 0         Canada_5_1758454485
# 1         Canada_1_1758454485
# 2         Canada_2_1758454485
# 3         Canada_3_1758454485
# 4         Canada_9_1758454487
# ...                       ...
# 25866  Canada_8171_1758479609
# 25867  Canada_8173_1758479609
# 25868  Canada_8180_1758479610
# 25869  Canada_8181_1758479616
# 25870  Canada_8183_1758479617
#
#                                                      url  \
# 0      https://www.canada.ca/aboutgov-ausujetgouv/dep...
# 1                                 https://www.canada.ca/
# 2                                      http://canada.ca/
# 3        https://www.canada.ca/?ref=university.heavnn.io
# 4                         https://canada.ca/accueil.html
# ...                                                  ...
# 25866  https://www.canada.ca/fr/ministere-defense-nat...
# 25867                      https://ncc-ccn.gc.ca/podcast
# 25868  https://www.guichetemplois.gc.ca/analyse-tenda...
# 25869  https://tc.canada.ca/en/aviation/reference-cen...
# 25870  https://www.nserc-crsng.gc.ca/InterAgency-Inte...
#
#                                                    title description  \
# 0                   Departments and agencies - Canada.ca
# 1                                              Canada.ca
# 2                                              Canada.ca
# 3                                              Canada.ca
# 4                                    Accueil - Canada.ca
# ...                                                  ...         ...
# 25866  Manuel sur la politique des congés des Forces ...
# 25867  Capital Stories: An NCC podcast series | Natio...
# 25868  Explorer le marché du travail au Canada - Guic...
# 25869                 Advisory Circular (AC) No. 302-015
# 25870  NSERC - Inter-Agency, Tri-Agency Financial Adm...
#
#                                                  content province  \
# 0      Departments and agencies\n\nEnter a department...   Canada
# 1      Canada.ca\n/ Gouvernement du Canada\nGovernmen...   Canada
# 2      Canada.ca\n/ Gouvernement du Canada\nGovernmen...   Canada
# 3      Canada.ca\n/ Gouvernement du Canada\nGovernmen...   Canada
# 4      Canada.ca\n\nLe site officiel du gouvernement ...   Canada
# ...                                                  ...      ...
# 25866  Manuel de la politique des congés des Forces c...   Canada
# 25867  You are here: Home Capital Stories: An NCC pod...   Canada
# 25868  Explorer le marché du travail au Canada\n\nAcc...   Canada
# 25869  Advisory Circular (AC) No. 302-015\n\nFrom: Tr...   Canada
# 25870  Tri-agency financial administration\nSummary o...   Canada
#
#           timestamp  content_length language      source document_type
# 0      1.758454e+09            8452       en  canada_gov          html
# 1      1.758454e+09             160       en  canada_gov          html
# 2      1.758454e+09             160       en  canada_gov          html
# 3      1.758454e+09             160       en  canada_gov          html
# 4      1.758454e+09            2294       en  canada_gov          html
# ...             ...             ...      ...         ...           ...
# 25866  1.758480e+09             298       fr  canada_gov           NaN
# 25867  1.758480e+09            3616       en  canada_gov           NaN
# 25868  1.758480e+09            1323       en  canada_gov           NaN
# 25869  1.758480e+09           12621       en  canada_gov           NaN
# 25870  1.758480e+09            3301       en  canada_gov           NaN
#
# [25871 rows x 11 columns]

# %%
def id_fixed(id):

  index_count = str(canada_df.index[canada_df['id'] == str(id)].tolist()[0])

  list_id = id.split('_')
  list_id[1] = index_count

  return "_".join(list_id)

id_fixed("Canada_8173_1758479609")
# Out:
# 'Canada_25867_1758479609'

# %%
canada_df["id"] = canada_df["id"].apply(id_fixed)

# %%
canada_df
# Out:
#                             id  \
# 0          Canada_0_1758454485
# 1          Canada_1_1758454485
# 2          Canada_2_1758454485
# 3          Canada_3_1758454485
# 4          Canada_4_1758454487
# ...                        ...
# 25866  Canada_25866_1758479609
# 25867  Canada_25867_1758479609
# 25868  Canada_25868_1758479610
# 25869  Canada_25869_1758479616
# 25870  Canada_25870_1758479617
#
#                                                      url  \
# 0      https://www.canada.ca/aboutgov-ausujetgouv/dep...
# 1                                 https://www.canada.ca/
# 2                                      http://canada.ca/
# 3        https://www.canada.ca/?ref=university.heavnn.io
# 4                         https://canada.ca/accueil.html
# ...                                                  ...
# 25866  https://www.canada.ca/fr/ministere-defense-nat...
# 25867                      https://ncc-ccn.gc.ca/podcast
# 25868  https://www.guichetemplois.gc.ca/analyse-tenda...
# 25869  https://tc.canada.ca/en/aviation/reference-cen...
# 25870  https://www.nserc-crsng.gc.ca/InterAgency-Inte...
#
#                                                    title description  \
# 0                   Departments and agencies - Canada.ca
# 1                                              Canada.ca
# 2                                              Canada.ca
# 3                                              Canada.ca
# 4                                    Accueil - Canada.ca
# ...                                                  ...         ...
# 25866  Manuel sur la politique des congés des Forces ...
# 25867  Capital Stories: An NCC podcast series | Natio...
# 25868  Explorer le marché du travail au Canada - Guic...
# 25869                 Advisory Circular (AC) No. 302-015
# 25870  NSERC - Inter-Agency, Tri-Agency Financial Adm...
#
#                                                  content province  \
# 0      Departments and agencies\n\nEnter a department...   Canada
# 1      Canada.ca\n/ Gouvernement du Canada\nGovernmen...   Canada
# 2      Canada.ca\n/ Gouvernement du Canada\nGovernmen...   Canada
# 3      Canada.ca\n/ Gouvernement du Canada\nGovernmen...   Canada
# 4      Canada.ca\n\nLe site officiel du gouvernement ...   Canada
# ...                                                  ...      ...
# 25866  Manuel de la politique des congés des Forces c...   Canada
# 25867  You are here: Home Capital Stories: An NCC pod...   Canada
# 25868  Explorer le marché du travail au Canada\n\nAcc...   Canada
# 25869  Advisory Circular (AC) No. 302-015\n\nFrom: Tr...   Canada
# 25870  Tri-agency financial administration\nSummary o...   Canada
#
#           timestamp  content_length language      source document_type
# 0      1.758454e+09            8452       en  canada_gov          html
# 1      1.758454e+09             160       en  canada_gov          html
# 2      1.758454e+09             160       en  canada_gov          html
# 3      1.758454e+09             160       en  canada_gov          html
# 4      1.758454e+09            2294       en  canada_gov          html
# ...             ...             ...      ...         ...           ...
# 25866  1.758480e+09             298       fr  canada_gov           NaN
# 25867  1.758480e+09            3616       en  canada_gov           NaN
# 25868  1.758480e+09            1323       en  canada_gov           NaN
# 25869  1.758480e+09           12621       en  canada_gov           NaN
# 25870  1.758480e+09            3301       en  canada_gov           NaN
#
# [25871 rows x 11 columns]

# %%
df_without_canada = df1[~df1['id'].str.contains('Canada', case=False)]

# %%
df_combined = pd.concat([df_without_canada, canada_df], ignore_index=True)

# %%
df_combined.sample(5)
# Out:
#                                      id  \
# 11438  British_Columbia_5897_1757140937
# 81709            Canada_8066_1758463670
# 94987           Canada_21344_1758461931
# 40909           Ontario_1768_1757168915
# 66070            Quebec_9207_1758390865
#
#                                                      url  \
# 11438  https://www2.gov.bc.ca/gov/content/health/prac...
# 81709  https://www.canada.ca/en/immigration-refugees-...
# 94987  https://www.diigo.com/post?title=Find+a+job+-+...
# 40909  https://www.ontario.ca/foodland/recipes/strawb...
# 66070  https://www.quebec.ca/tourisme-et-loisirs/aide...
#
#                                                    title  \
# 11438  8.7 Capitation Fees for Plan B (Long-term Care...
# 81709       Notice – Adoptions from Pakistan - Canada.ca
# 94987                           Sign in to Diigo | Diigo
# 40909                              Government of Ontario
# 66070   Programme Équipe Québec | Gouvernement du Québec
#
#                                              description  \
# 11438  8.7 Capitation Fees for Plan B (Residential Care)
# 81709
# 94987
# 40909                                               None
# 66070  Aide financière offerte aux athlètes qui parti...
#
#                                                  content          province  \
# 11438    * \n\ncovers B.C. residents who are permanen...  British_Columbia
# 81709  Notice – Adoptions from Pakistan\n\nThe provin...            Canada
# 94987  Sign in diigo\nSign in\nForgot password?\n\nSi...            Canada
# 40909  We’re receiving a higher volume of requests fr...           Ontario
# 66070    1. [Aides financières en sport, loisir, acti...            Quebec
#
#           timestamp  content_length language      source document_type
# 11438  1.757141e+09            4616       fr  canada_gov          html
# 81709  1.758464e+09             954       en  canada_gov          html
# 94987  1.758462e+09             172       en  canada_gov           NaN
# 40909  1.757169e+09             611       fr  canada_gov          html
# 66070  1.758391e+09            1491       fr  canada_gov          html

# %%
df_combined['document_type'] = df_combined['document_type'].fillna('html')

# %%
df_combined.drop_duplicates(subset=['url'], inplace=True)

# %%
from langdetect import detect, LangDetectException

def detect_language(text: str, fallback="en") -> str:
    try:
        lang = detect(text.strip()[:500])
        return "fr" if lang == "fr" else "en"
    except:
        return fallback

# %%
df_combined['language'] = df_combined["content"].apply(detect_language)

# %%
df_combined.sample(5)
# Out:
#                                          id  \
# 54854  Prince_Edward_Island_1536_1757192170
# 29894        New_Brunswick_13076_1757190903
# 88403               Canada_14760_1758368985
# 59103             Quebec_pdf_408_1758363751
# 52160              Ontario_13066_1757179430
#
#                                                      url  \
# 54854  https://www.princeedwardisland.ca/en/informati...
# 29894  https://laws.gnb.ca/en/version/cs/P-5.05?code=...
# 88403  https://open.canada.ca/en/search/ati?ati%5B0%5...
# 59103  https://cdn-contenu.quebec.ca/cdn-contenu/adm/...
# 52160  https://www.ontario.ca/page/covid-19-workplace...
#
#                                                    title  \
# 54854                                    400 Bad Request
# 29894                               Disposition versions
# 88403  Completed Access to Information Requests | Ope...
# 59103                              FORM-Fr_SAJMA_MJQ.pdf
# 52160  COVID-19 and workplace health and safety | ont...
#
#                                              description  \
# 54854                                               None
# 29894                                               None
# 88403  About this information Search the summaries of...
# 59103                            Government PDF document
# 52160  Get information and tools to help you protect ...
#
#                                                  content  \
# 54854  Your browser sent a request that this server c...
# 29894  If either an employer or a bargaining agent ha...
# 88403  Search the summaries of completed Access to In...
# 59103  Page 1 de 13\nMinistère de la JusticeMJQ-905 1...
# 52160  Get information and tools to help you protect ...
#
#                    province     timestamp  content_length language  \
# 54854  Prince_Edward_Island  1.757192e+09             120       en
# 29894         New_Brunswick  1.757191e+09             770       en
# 88403                Canada  1.758369e+09            4041       en
# 59103                Quebec  1.758364e+09           34439       fr
# 52160               Ontario  1.757179e+09            1524       en
#
#            source document_type
# 54854  canada_gov          html
# 29894  canada_gov          html
# 88403  canada_gov          html
# 59103  canada_gov           pdf
# 52160  canada_gov          html

# %%
from urllib.parse import urlparse

def extract_source_from_url(url: str) -> str:
    domain = urlparse(url).netloc.lower()
    # Remove 'www.' and '.gc.ca' / '.ca' suffixes
    if domain.startswith("www."):
        domain = domain[4:]
    if domain.endswith(".gc.ca"):
        domain = domain[:-6]  # e.g., "tc.gc.ca" → "tc"
    elif domain.endswith(".ca"):
        domain = domain[:-3]  # e.g., "alberta.ca" → "alberta"
    return domain.replace(".", "_") + "_gov"  # e.g., "ncc_ccn" → "ncc_ccn_gov"

# %%
df_combined['source'] = df_combined['url'].apply(extract_source_from_url)

# %%
df_combined
# Out:
#                             id  \
# 0         Alberta_1_1757152647
# 1         Alberta_2_1757152647
# 2         Alberta_3_1757152647
# 3         Alberta_4_1757152648
# 4         Alberta_5_1757152648
# ...                        ...
# 99509  Canada_25866_1758479609
# 99510  Canada_25867_1758479609
# 99511  Canada_25868_1758479610
# 99512  Canada_25869_1758479616
# 99513  Canada_25870_1758479617
#
#                                                      url  \
# 0      https://www.alberta.ca/careers-fisheries-manag...
# 1      https://www.alberta.ca/carrier-profiles-and-mo...
# 2         https://www.alberta.ca/careers-land-management
# 3      https://www.alberta.ca/careers-wildlife-manage...
# 4                https://www.alberta.ca/careers-agrology
# ...                                                  ...
# 99509  https://www.canada.ca/fr/ministere-defense-nat...
# 99510                      https://ncc-ccn.gc.ca/podcast
# 99511  https://www.guichetemplois.gc.ca/analyse-tenda...
# 99512  https://tc.canada.ca/en/aviation/reference-cen...
# 99513  https://www.nserc-crsng.gc.ca/InterAgency-Inte...
#
#                                                    title  \
# 0            Careers – Fisheries management | Alberta.ca
# 1           Carrier profiles and monitoring | Alberta.ca
# 2                 Careers – Land management | Alberta.ca
# 3             Careers – Wildlife management | Alberta.ca
# 4                        Careers – Agrology | Alberta.ca
# ...                                                  ...
# 99509  Manuel sur la politique des congés des Forces ...
# 99510  Capital Stories: An NCC podcast series | Natio...
# 99511  Explorer le marché du travail au Canada - Guic...
# 99512                 Advisory Circular (AC) No. 302-015
# 99513  NSERC - Inter-Agency, Tri-Agency Financial Adm...
#
#                                              description  \
# 0      A career in fisheries management offers many o...
# 1      Supports carriers' internal monitoring of on-r...
# 2      There are many rewarding career paths for land...
# 3      A career in wildlife management offers opportu...
# 4      Agrologists can find meaningful work managing ...
# ...                                                  ...
# 99509
# 99510
# 99511
# 99512
# 99513
#
#                                                  content province  \
# 0      A career in fisheries management offers many o...  Alberta
# 1      \n\n\n\n  * Effective December 2020, the Roads...  Alberta
# 2      The Lands Division is responsible for providin...  Alberta
# 3      A career in Wildlife Management offers a contr...  Alberta
# 4      Consider a career that enables you to make a d...  Alberta
# ...                                                  ...      ...
# 99509  Manuel de la politique des congés des Forces c...   Canada
# 99510  You are here: Home Capital Stories: An NCC pod...   Canada
# 99511  Explorer le marché du travail au Canada\n\nAcc...   Canada
# 99512  Advisory Circular (AC) No. 302-015\n\nFrom: Tr...   Canada
# 99513  Tri-agency financial administration\nSummary o...   Canada
#
#           timestamp  content_length language              source document_type
# 0      1.757153e+09            4794       en         alberta_gov          html
# 1      1.757153e+09            5891       en         alberta_gov          html
# 2      1.757153e+09            6423       en         alberta_gov          html
# 3      1.757153e+09            3919       en         alberta_gov          html
# 4      1.757153e+09            4653       en         alberta_gov          html
# ...             ...             ...      ...                 ...           ...
# 99509  1.758480e+09             298       fr          canada_gov          html
# 99510  1.758480e+09            3616       en         ncc-ccn_gov          html
# 99511  1.758480e+09            1323       fr  guichetemplois_gov          html
# 99512  1.758480e+09           12621       en       tc_canada_gov          html
# 99513  1.758480e+09            3301       en     nserc-crsng_gov          html
#
# [99514 rows x 11 columns]

# %%
df_combined.to_csv("combined_canada_rag_cleaned.csv", index=False, encoding="utf-8")
df_combined.to_json("combined_canada_rag_cleaned.jsonl", orient="records", lines=True, force_ascii=False)
